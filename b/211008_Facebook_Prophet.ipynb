# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls -l '/content/drive/MyDrive/Colab Notebooks/datasets/양파.xlsx'
# Out:
# -rw------- 1 root root 12405551 Oct  8 08:18 '/content/drive/MyDrive/Colab Notebooks/datasets/양파.xlsx'

# %%
from fbprophet import Prophet
import pandas as pd
df = pd.read_excel('/content/14~21년 양파 일별 도매가격 변화.xlsx')

# %%
m = Prophet()
m.fit(df[:2000])
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
len(df)
# Out:
# 2398

# %%
df.head()
# Out:
#           ds           y
# 0 2014-01-03  732.050561
# 1 2014-01-04  750.217872
# 2 2014-01-06  711.908712
# 3 2014-01-07  726.198892
# 4 2014-01-08  694.834671

# %%
future.head()
# Out:
#           ds
# 0 2014-01-03
# 1 2014-01-04
# 2 2014-01-06
# 3 2014-01-07
# 4 2014-01-08

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 2360 2021-06-15
# 2361 2021-06-16
# 2362 2021-06-17
# 2363 2021-06-18
# 2364 2021-06-19

# %%
forecast = m.predict(future)
forecast.tail()
# Out:
#              ds        trend  ...  multiplicative_terms_upper        yhat
# 2360 2021-06-15  1083.345814  ...                         0.0  949.569101
# 2361 2021-06-16  1084.146733  ...                         0.0  956.343790
# 2362 2021-06-17  1084.947652  ...                         0.0  951.745416
# 2363 2021-06-18  1085.748571  ...                         0.0  952.937872
# 2364 2021-06-19  1086.549490  ...                         0.0  956.989941
#
# [5 rows x 19 columns]

# %%
from matplotlib import pyplot as plt
import numpy as np

plt.plot(x = df['ds'], y = df['y'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-4a293c9790b5> in <module>()
#       2 import numpy as np
#       3
# ----> 4 plt.plot(x = df['ds'], y = df['y'])
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     157             if pos_only in kwargs:
#     158                 raise TypeError("{} got an unexpected keyword argument {!r}"
# --> 159                                 .format(self.command, pos_only))
#     160
#     161         if not args:
#
# TypeError: plot got an unexpected keyword argument 'x'

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)
